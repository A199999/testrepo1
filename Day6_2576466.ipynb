# %%
# Question1
class Shape:
    def calculate_area(self):
        pass

    def calculate_perimeter(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14159 * self.radius * self.radius

    def calculate_perimeter(self):
        return 2 * 3.14159 * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)

circle = Circle(5)
print("Circle - Area:", circle.calculate_area())
print("Circle - Perimeter:", circle.calculate_perimeter())

rectangle = Rectangle(4, 6)
print("Rectangle - Area:", rectangle.calculate_area())
print("Rectangle - Perimeter:", rectangle.calculate_perimeter())
# Out:
# Circle - Area: 78.53975
# Circle - Perimeter: 31.4159
# Rectangle - Area: 24
# Rectangle - Perimeter: 20

# %%
class Question:
    def __init__(self, question_text, correct_answer):
        self.question_text = question_text
        self.correct_answer = correct_answer

class Quiz:
    def __init__(self, name):
        self.name = name
        self.questions = []
        self.score = 0

    def add_question(self, question_text, correct_answer):
        question = Question(question_text, correct_answer)
        self.questions.append(question)

    def take_quiz(self):
        print(f"Welcome to the {self.name} Quiz!")
        for i, question in enumerate(self.questions, start=1):
            print(f"Question {i}: {question.question_text}")
            user_answer = input("Your answer: ")
            if user_answer == question.correct_answer:
                self.score += 1
        print(f"Quiz completed! Your score: {self.score}/{len(self.questions)}")

python_quiz = Quiz("Python Programming")
python_quiz.add_question("What is the capital of France?", "Paris")
python_quiz.add_question("What is 2 + 2?", "4")
python_quiz.add_question("What is the largest planet in our solar system?", "Jupiter")

python_quiz.take_quiz()

user_progress = {}
user_name = input("Enter your name: ")
user_progress[user_name] = {
    "quiz_name": python_quiz.name,
    "score": python_quiz.score,
    "quiz_date": "2023-09-18",  # You can use the actual date here
}

if user_name in user_progress:
    user_data = user_progress[user_name]
    print(f"{user_name}'s Quiz Progress:")
    print(f"Quiz Name: {user_data['quiz_name']}")
    print(f"Score: {user_data['score']}")
    print(f"Quiz Date: {user_data['quiz_date']}")
else:
    print(f"No progress found for {user_name}.")
# Out:
# Welcome to the Python Programming Quiz!
# Question 1: What is the capital of France?
# Your answer: paris
# Question 2: What is 2 + 2?
# Your answer: 4
# Question 3: What is the largest planet in our solar system?
# Your answer: jupiter
# Quiz completed! Your score: 1/3
# Enter your name: abhinav
# abhinav's Quiz Progress:
# Quiz Name: Python Programming
# Score: 1
# Quiz Date: 2023-09-18

# %%
#question2
class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age  

    def get_age(self):
        return self.__age

    def check_voting_eligibility(self):
        if self.__age >= 18:
            return f"{self.__name} is eligible to vote."
        else:
            return f"{self.__name} is not eligible to vote."


person1 = Person("Alice", 25)


print(f"{person1.get_age()} years old")


print(person1.check_voting_eligibility())
# Out:
# 25 years old
# Alice is eligible to vote.

# %%
#question 3
class BankAccount:
    def __init__(self, account_number, account_holder_name, balance):
        self.__account_number = account_number
        self.__account_holder_name = account_holder_name
        self.__balance = balance

    def get_account_number(self):
        return self.__account_number

    def get_account_holder_name(self):
        return self.__account_holder_name

    def get_balance(self):
        return self.__balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"Deposited ${amount}. New balance: ${self.__balance}")
        else:
            print("Invalid deposit amount. Please enter a positive value.")

    def withdraw(self, amount):
        if amount > 0:
            if self.__balance >= amount:
                self.__balance -= amount
                print(f"Withdrew ${amount}. New balance: ${self.__balance}")
            else:
                print("Insufficient funds.")
        else:
            print("Invalid withdrawal amount. Please enter a positive value.")

class SavingsAccount(BankAccount):
    def __init__(self, account_number, account_holder_name, balance, interest_rate):
        super().__init__(account_number, account_holder_name, balance)
        self.__interest_rate = interest_rate

    def get_interest_rate(self):
        return self.__interest_rate

    def calculate_interest(self):
        interest = (self.get_balance() * self.__interest_rate) / 100
        self.deposit(interest)
        print(f"Interest calculated and added. New balance: ${self.get_balance()}")

class CheckingAccount(BankAccount):
    def __init__(self, account_number, account_holder_name, balance, overdraft_limit):
        super().__init__(account_number, account_holder_name, balance)
        self.__overdraft_limit = overdraft_limit

    def get_overdraft_limit(self):
        return self.__overdraft_limit

    def withdraw(self, amount):
        if amount > 0:
            available_balance = self.get_balance() + self.__overdraft_limit
            if available_balance >= amount:
                self.__balance -= amount
                print(f"Withdrew ${amount}. New balance: ${self.get_balance()}")
            else:
                print("Insufficient funds (including overdraft).")
        else:
            print("Invalid withdrawal amount. Please enter a positive value.")

# Example usage
if __name__ == "__main__":
    # Create instances of SavingsAccount and CheckingAccount
    savings_account = SavingsAccount("SA123", "John Doe", 1000, 5.0)
    checking_account = CheckingAccount("CA456", "Jane Smith", 500, 200)

    # Deposit and withdraw from SavingsAccount
    savings_account.deposit(500)
    savings_account.calculate_interest()
    savings_account.withdraw(200)

    # Deposit and withdraw from CheckingAccount
    checking_account.deposit(300)
    checking_account.withdraw(700)  # Should use overdraft
    checking_account.withdraw(800)  # Not enough balance or overdraft

    # Access account information
    print(f"Savings Account: {savings_account.get_account_holder_name()}, Balance: ${savings_account.get_balance()}")
    print(f"Checking Account: {checking_account.get_account_holder_name()}, Balance: ${checking_account.get_balance()}")
# Out:
# Deposited $500. New balance: $1500
# Deposited $75.0. New balance: $1575.0
# Interest calculated and added. New balance: $1575.0
# Withdrew $200. New balance: $1375.0
# Deposited $300. New balance: $800
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 79
#      77 # Deposit and withdraw from CheckingAccount
#      78 checking_account.deposit(300)
# ---> 79 checking_account.withdraw(700)  # Should use overdraft
#      80 checking_account.withdraw(800)  # Not enough balance or overdraft
#      82 # Access account information
#
# Cell In[6], line 59, in CheckingAccount.withdraw(self, amount)
#      57 available_balance = self.get_balance() + self.__overdraft_limit
#      58 if available_balance >= amount:
# ---> 59     self.__balance -= amount
#      60     print(f"Withdrew ${amount}. New balance: ${self.get_balance()}")
#      61 else:
#
# ...

# %%
#question4
class Employee:
    def __init__(self, name, employee_id):
        self.__name = name
        self.__employee_id = employee_id
        self.__salary = 0  # Default salary

    def get_name(self):
        return self.__name

    def set_name(self, name):
        self.__name = name

    def get_employee_id(self):
        return self.__employee_id

    def set_employee_id(self, employee_id):
        self.__employee_id = employee_id

    def get_salary(self):
        return self.__salary

    def set_salary(self, salary):
        self.__salary = salary

    def calculate_salary(self):
        pass  # To be overridden in subclasses


class FullTimeEmployee(Employee):
    def __init__(self, name, employee_id, annual_salary):
        super().__init__(name, employee_id)
        self.__annual_salary = annual_salary

    def get_annual_salary(self):
        return self.__annual_salary

    def set_annual_salary(self, annual_salary):
        self.__annual_salary = annual_salary

    def calculate_salary(self):
        return self.__annual_salary / 12  # Monthly salary for full-time employees


class PartTimeEmployee(Employee):
    def __init__(self, name, employee_id, hours_worked, hourly_rate):
        super().__init__(name, employee_id)
        self.__hours_worked = hours_worked
        self.__hourly_rate = hourly_rate

    def get_hours_worked(self):
        return self.__hours_worked

    def set_hours_worked(self, hours_worked):
        self.__hours_worked = hours_worked

    def get_hourly_rate(self):
        return self.__hourly_rate

    def set_hourly_rate(self, hourly_rate):
        self.__hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.__hours_worked * self.__hourly_rate  # Monthly salary for part-time employees


# Create instances of FullTimeEmployee and PartTimeEmployee
full_time_employee = FullTimeEmployee("John Smith", "FT123", 60000)
part_time_employee = PartTimeEmployee("Jane Doe", "PT456", 160, 15.5)

# Calculate and display salaries
print(f"{full_time_employee.get_name()} ({full_time_employee.get_employee_id()}): Monthly Salary - ${full_time_employee.calculate_salary()}")
print(f"{part_time_employee.get_name()} ({part_time_employee.get_employee_id()}): Monthly Salary - ${part_time_employee.calculate_salary()}")
# Out:
# John Smith (FT123): Monthly Salary - $5000.0
# Jane Doe (PT456): Monthly Salary - $2480.0

# %%
#question5
import datetime

class Book:
    def __init__(self, title, author, publication_date):
        self.__title = title
        self.__author = author
        self.__publication_date = publication_date
        self.__is_checked_out = False

    def get_title(self):
        return self.__title

    def get_author(self):
        return self.__author

    def get_publication_date(self):
        return self.__publication_date

    def is_checked_out(self):
        return self.__is_checked_out

    def check_out(self):
        if not self.__is_checked_out:
            self.__is_checked_out = True
            print(f"'{self.__title}' by {self.__author} is checked out.")
        else:
            print(f"'{self.__title}' is already checked out.")

    def return_book(self):
        if self.__is_checked_out:
            self.__is_checked_out = False
            print(f"'{self.__title}' by {self.__author} has been returned.")
        else:
            print(f"'{self.__title}' is not checked out.")

    def is_overdue(self, due_date):
        if self.__is_checked_out and datetime.date.today() > due_date:
            return True
        return False


class Patron:
    def __init__(self, name, library_card_number):
        self.__name = name
        self.__library_card_number = library_card_number
        self.__checked_out_books = []

    def get_name(self):
        return self.__name

    def get_library_card_number(self):
        return self.__library_card_number

    def check_out_book(self, book):
        if len(self.__checked_out_books) < 3:  # Patron can check out up to 3 books
            book.check_out()
            self.__checked_out_books.append(book)
        else:
            print("You have reached the maximum limit of checked-out books.")

    def return_book(self, book):
        if book in self.__checked_out_books:
            book.return_book()
            self.__checked_out_books.remove(book)
        else:
            print("You did not check out this book from the library.")

    def get_checked_out_books(self):
        return self.__checked_out_books


class Transaction:
    @staticmethod
    def notify_overdue_books(patrons, due_date):
        for patron in patrons:
            checked_out_books = patron.get_checked_out_books()
            for book in checked_out_books:
                if book.is_overdue(due_date):
                    print(f"{patron.get_name()}: '{book.get_title()}' is overdue!")

book1 = Book("The Great Gatsby", "F. Scott Fitzgerald", datetime.date(1925, 4, 10))
book2 = Book("To Kill a Mockingbird", "Harper Lee", datetime.date(1960, 7, 11))

patron1 = Patron("Alice", "LIB123")
patron2 = Patron("Bob", "LIB456")

patron1.check_out_book(book1)
patron2.check_out_book(book2)
patron1.return_book(book1)

due_date = datetime.date(2023, 9, 30)
Transaction.notify_overdue_books([patron1, patron2], due_date)
# Out:
# 'The Great Gatsby' by F. Scott Fitzgerald is checked out.
# 'To Kill a Mockingbird' by Harper Lee is checked out.
# 'The Great Gatsby' by F. Scott Fitzgerald has been returned.

# %%
#question6
class Product:
    def __init__(self, product_id, name, price):
        self.__product_id = product_id
        self.__name = name
        self.__price = price
        self.__is_in_stock = True

    def get_product_id(self):
        return self.__product_id

    def get_name(self):
        return self.__name

    def get_price(self):
        return self.__price

    def is_in_stock(self):
        return self.__is_in_stock

    def set_in_stock(self, in_stock):
        self.__is_in_stock = in_stock

    def calculate_shipping_cost(self, destination):
        # Calculate shipping cost based on destination (simplified)
        return 10.0  # Fixed shipping cost for demonstration


class ElectronicProduct(Product):
    def __init__(self, product_id, name, price, brand):
        super().__init__(product_id, name, price)
        self.__brand = brand

    def get_brand(self):
        return self.__brand

    def calculate_shipping_cost(self, destination):
        # Calculate shipping cost for electronics based on destination (simplified)
        return 15.0  # Higher shipping cost for electronics


class ClothingProduct(Product):
    def __init__(self, product_id, name, price, size):
        super().__init__(product_id, name, price)
        self.__size = size

    def get_size(self):
        return self.__size

    def calculate_shipping_cost(self, destination):
        # Calculate shipping cost for clothing based on destination (simplified)
        return 8.0  # Lower shipping cost for clothing


class ShoppingCart:
    def __init__(self):
        self.__items = []

    def add_product(self, product):
        if product.is_in_stock():
            self.__items.append(product)
            product.set_in_stock(False)  # Mark as out of stock after adding to cart

    def remove_product(self, product):
        if product in self.__items:
            self.__items.remove(product)
            product.set_in_stock(True)  # Mark as in stock after removing from cart

    def calculate_total_cost(self, destination):
        total_cost = 0.0
        for item in self.__items:
            total_cost += item.get_price() + item.calculate_shipping_cost(destination)
        return total_cost


class Order:
    def __init__(self, order_id, cart, shipping_address):
        self.__order_id = order_id
        self.__cart = cart
        self.__shipping_address = shipping_address

    def get_order_id(self):
        return self.__order_id

    def place_order(self):
        # Simulate placing an order (e.g., updating inventory, processing payment)
        print(f"Order {self.__order_id} placed successfully.")
